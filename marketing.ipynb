# %%
import os

print(os.getcwd())
# Out:
# C:\Users\SARITHA\PycharmProjects\python Project

# %%
import pandas as pd

df = pd.read_csv("data csv/marketing_campaign_data.csv")
print(df.head())
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0    342199        1985  Graduation       Together  59011.7        1
# 1   8075450        1975      Master         Single   1730.0        1
# 2  13664263        1978  Graduation        Married  98584.6        0
# 3  16164787        1976  Graduation        Married  74031.5        1
# 4  15815139        1981  Graduation       Divorced  52784.2        1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0  2012-11-17        3         0  ...                  3
# 1         1  2013-04-10       96         0  ...                  2
# 2         0  2014-01-11       99       920  ...                  6
# 3         0  2014-06-18       47       265  ...                 11
# 4         1  2014-05-20        0        30  ...                  3
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
print(df.head())
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0    342199        1985  Graduation       Together  59011.7        1
# 1   8075450        1975      Master         Single   1730.0        1
# 2  13664263        1978  Graduation        Married  98584.6        0
# 3  16164787        1976  Graduation        Married  74031.5        1
# 4  15815139        1981  Graduation       Divorced  52784.2        1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0  2012-11-17        3         0  ...                  3
# 1         1  2013-04-10       96         0  ...                  2
# 2         0  2014-01-11       99       920  ...                  6
# 3         0  2014-06-18       47       265  ...                 11
# 4         1  2014-05-20        0        30  ...                  3
#
#    NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 56000 entries, 0 to 55999
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   56000 non-null  int64
#  1   Year_Birth           56000 non-null  int64
#  2   Education            56000 non-null  str
#  3   Marital_Status       56000 non-null  str
#  4   Income               56000 non-null  float64
#  5   Kidhome              56000 non-null  int64
#  6   Teenhome             56000 non-null  int64
#  7   Dt_Customer          56000 non-null  str
#  8   Recency              56000 non-null  int64
#  9   MntWines             56000 non-null  int64
#  10  MntFruits            56000 non-null  int64
#  11  MntMeatProducts      56000 non-null  int64
#  12  MntFishProducts      56000 non-null  int64
#  13  MntSweetProducts     56000 non-null  int64
#  14  MntGoldProds         56000 non-null  int64
#  15  NumDealsPurchases    56000 non-null  int64
# ...

# %%
print(df.shape)
# Out:
# (56000, 28)

# %%
print(df.columns)
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='str')

# %%
print(df.isnull().sum())
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %%
#step 3 handle missing values
df["Income"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Income"] = df["Income"].fillna(df["Income"].median())

# %%
df["Income"].isnull().sum()
# Out:
# np.int64(0)

# %%
print(df.isnull().sum())
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %%
#step 4 convert data
df["Dt_Customer"] = pd.to_datetime(df["Dt_Customer"])

# %%
from datetime import datetime

current_year = datetime.now().year
df["Age"] = current_year - df["Year_Birth"]

# %%
df["Children"] = df["Kidhome"] + df["Teenhome"]

# %%
df["Total_Spending"] = (
    df["MntWines"]
    + df["MntFruits"]
    + df["MntMeatProducts"]
    + df["MntFishProducts"]
    + df["MntSweetProducts"]
    + df["MntGoldProds"]
)

# %%
df["Total_Purchases"] = (
    df["NumWebPurchases"]
    + df["NumCatalogPurchases"]
    + df["NumStorePurchases"]
)

# %%
df["Total_Campaigns_Accepted"] = (
    df["AcceptedCmp1"]
    + df["AcceptedCmp2"]
    + df["AcceptedCmp3"]
    + df["AcceptedCmp4"]
    + df["AcceptedCmp5"]
)

# %%
print(df[[
    "Age",
    "Children",
    "Total_Spending",
    "Total_Purchases",
    "Total_Campaigns_Accepted"
]].head())
# Out:
#    Age  Children  Total_Spending  Total_Purchases  Total_Campaigns_Accepted
# 0   41         1              69               10                         0
# 1   51         2              39                3                         0
# 2   48         0            1512                9                         0
# 3   50         1             478               15                         0
# 4   45         2             330                8                         0

# %%
import pandas as pd
from datetime import datetime

df = pd.read_csv("data csv/marketing_campaign_data.csv")

# Data cleaning
df["Dt_Customer"] = pd.to_datetime(df["Dt_Customer"])

current_year = datetime.now().year
df["Age"] = current_year - df["Year_Birth"]

df["Children"] = df["Kidhome"] + df["Teenhome"]

df["Total_Spending"] = (
    df["MntWines"] +
    df["MntFruits"] +
    df["MntMeatProducts"] +
    df["MntFishProducts"] +
    df["MntSweetProducts"] +
    df["MntGoldProds"]
)

# Save cleaned data
df.to_csv("data csv/marketing_campaign_cleaned.csv", index=False)

# %%
df = pd.read_csv("data csv/marketing_campaign_cleaned.csv")

# %%
print(df.columns.tolist())
# Out:
# ['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain', 'Country', 'Age', 'Children', 'Total_Spending']

# %%
df["Total_Purchases"] = (
    df["NumWebPurchases"]
    + df["NumCatalogPurchases"]
    + df["NumStorePurchases"]
)

df["Total_Campaigns_Accepted"] = (
    df["AcceptedCmp1"]
    + df["AcceptedCmp2"]
    + df["AcceptedCmp3"]
    + df["AcceptedCmp4"]
    + df["AcceptedCmp5"]
)

# %%
print(df.shape)
# Out:
# (56000, 33)

# %%
print(len(df.columns))
print(df.columns.tolist())
# Out:
# 33
# ['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain', 'Country', 'Age', 'Children', 'Total_Spending', 'Total_Purchases', 'Total_Campaigns_Accepted']

# %%
df.to_csv("data csv/marketing_campaign_cleaned.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("data csv/marketing_campaign_cleaned.csv")

print(df.shape)
print(df.columns.tolist())
# Out:
# (56000, 33)
# ['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain', 'Country', 'Age', 'Children', 'Total_Spending', 'Total_Purchases', 'Total_Campaigns_Accepted']

# %%
print(query)
# Out:
# INSERT INTO marketing_analysis (
# ID, Year_Birth, Education, Marital_Status, Income,
# Kidhome, Teenhome, Dt_Customer, Recency,
# MntWines, MntFruits, MntMeatProducts, MntFishProducts,
# MntSweetProducts, MntGoldProds,
# NumDealsPurchases, NumWebPurchases,
# NumCatalogPurchases, NumStorePurchases,
# NumWebVisitsMonth,
# AcceptedCmp1, AcceptedCmp2, AcceptedCmp3,
# AcceptedCmp4, AcceptedCmp5,
# Response, Complain, Country,
# Age, Children, Total_Spending,
# Total_Purchases, Total_Campaigns_Accepted
# )
# VALUES (
# %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
# %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
# %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
# %s,%s,%s
# )

# %%
print(df["ID"].duplicated().sum())
# Out:
# 0

# %%
print("Rows in CSV:", len(df))
# Out:
# Rows in CSV: 56000

# %%
import pandas as pd
import mysql.connector

# Read CSV
df = pd.read_csv("data csv/marketing_campaign_cleaned.csv")

# Convert date format (if needed)
df["Dt_Customer"] = pd.to_datetime(
    df["Dt_Customer"],
    dayfirst=True
).dt.strftime("%Y-%m-%d")

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="guvi",      # Your MySQL password
    database="marketing"
)

cursor = conn.cursor()

# Insert query
query = """
INSERT INTO marketing_analysis (
ID, Year_Birth, Education, Marital_Status, Income,
Kidhome, Teenhome, Dt_Customer, Recency,
MntWines, MntFruits, MntMeatProducts, MntFishProducts,
MntSweetProducts, MntGoldProds,
NumDealsPurchases, NumWebPurchases,
NumCatalogPurchases, NumStorePurchases,
NumWebVisitsMonth,
AcceptedCmp1, AcceptedCmp2, AcceptedCmp3,
AcceptedCmp4, AcceptedCmp5,
Response, Complain, Country,
Age, Children, Total_Spending,
Total_Purchases, Total_Campaigns_Accepted
)
VALUES (
# %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
# %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
# %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
# %s,%s,%s
)
"""

# Convert DataFrame to list of tuples
values = [tuple(row) for row in df.itertuples(index=False, name=None)]

# Insert all rows at once
cursor.executemany(query, values)

conn.commit()

print(f"{cursor.rowcount} rows inserted successfully!")

cursor.close()
conn.close()
# Out:
# C:\Users\SARITHA\AppData\Local\Temp\ipykernel_14196\3417982459.py:8: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Dt_Customer"] = pd.to_datetime(
# 56000 rows inserted successfully!

# %%
import os

print(os.listdir("data csv"))
# Out:
# ['marketing_campaign_cleaned.csv']

# %%
df = pd.read_csv("data csv/marketing_campaign_cleaned.csv")

# %%
import pandas as pd

df = pd.read_csv(r"data csv\marketing_campaign_cleaned.csv")

# %%
df.head()
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0    342199        1985  Graduation       Together  59011.7        1
# 1   8075450        1975      Master         Single   1730.0        1
# 2  13664263        1978  Graduation        Married  98584.6        0
# 3  16164787        1976  Graduation        Married  74031.5        1
# 4  15815139        1981  Graduation       Divorced  52784.2        1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  AcceptedCmp1  AcceptedCmp2  \
# 0         0  2012-11-17        3         0  ...             0             0
# 1         1  2013-04-10       96         0  ...             0             0
# 2         0  2014-01-11       99       920  ...             0             0
# 3         0  2014-06-18       47       265  ...             0             0
# 4         1  2014-05-20        0        30  ...             0             0
#
#    Response  Complain    Country  Age  Children  Total_Spending  \
# ...

# %%
df.shape
# Out:
# (56000, 33)

# %%
import matplotlib.pyplot as plt

numeric_cols = [
    "Income",
    "MntWines",
    "MntFruits",
    "MntMeatProducts",
    "MntFishProducts",
    "MntSweetProducts",
    "MntGoldProds"
]

plt.figure(figsize=(15,8))
df[numeric_cols].boxplot()
plt.xticks(rotation=45)
plt.title("Outlier Detection using Boxplots")
plt.show()

# %%
df.isnull().sum()
# Out:
# ID                          0
# Year_Birth                  0
# Education                   0
# Marital_Status              0
# Income                      0
# Kidhome                     0
# Teenhome                    0
# Dt_Customer                 0
# Recency                     0
# MntWines                    0
# MntFruits                   0
# MntMeatProducts             0
# MntFishProducts             0
# MntSweetProducts            0
# MntGoldProds                0
# NumDealsPurchases           0
# NumWebPurchases             0
# NumCatalogPurchases         0
# NumStorePurchases           0
# NumWebVisitsMonth           0
# AcceptedCmp3                0
# AcceptedCmp4                0
# AcceptedCmp5                0
# AcceptedCmp1                0
# AcceptedCmp2                0
# Response                    0
# Complain                    0
# Country                     0
# Age                         0
# Children                    0
# Total_Spending              0
# ...

# %%
df.dtypes
# Out:
# ID                            int64
# Year_Birth                    int64
# Education                       str
# Marital_Status                  str
# Income                      float64
# Kidhome                       int64
# Teenhome                      int64
# Dt_Customer                     str
# Recency                       int64
# MntWines                      int64
# MntFruits                     int64
# MntMeatProducts               int64
# MntFishProducts               int64
# MntSweetProducts              int64
# MntGoldProds                  int64
# NumDealsPurchases             int64
# NumWebPurchases               int64
# NumCatalogPurchases           int64
# NumStorePurchases             int64
# NumWebVisitsMonth             int64
# AcceptedCmp3                  int64
# AcceptedCmp4                  int64
# AcceptedCmp5                  int64
# AcceptedCmp1                  int64
# AcceptedCmp2                  int64
# Response                      int64
# ...

# %%
df["Total_Spending"] = (
    df["MntWines"] +
    df["MntFruits"] +
    df["MntMeatProducts"] +
    df["MntFishProducts"] +
    df["MntSweetProducts"] +
    df["MntGoldProds"]
)

df.head()
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0    342199        1985  Graduation       Together  59011.7        1
# 1   8075450        1975      Master         Single   1730.0        1
# 2  13664263        1978  Graduation        Married  98584.6        0
# 3  16164787        1976  Graduation        Married  74031.5        1
# 4  15815139        1981  Graduation       Divorced  52784.2        1
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  AcceptedCmp1  AcceptedCmp2  \
# 0         0  2012-11-17        3         0  ...             0             0
# 1         1  2013-04-10       96         0  ...             0             0
# 2         0  2014-01-11       99       920  ...             0             0
# 3         0  2014-06-18       47       265  ...             0             0
# 4         1  2014-05-20        0        30  ...             0             0
#
#    Response  Complain    Country  Age  Children  Total_Spending  \
# ...

# %%
import matplotlib.pyplot as plt

products = [
    "MntWines",
    "MntFruits",
    "MntMeatProducts",
    "MntFishProducts",
    "MntSweetProducts",
    "MntGoldProds"
]

df[products].sum().plot(kind="bar")

plt.title("Total Spending by Product")
plt.ylabel("Amount")
plt.show()

# %%
campaigns = [
    "AcceptedCmp1",
    "AcceptedCmp2",
    "AcceptedCmp3",
    "AcceptedCmp4",
    "AcceptedCmp5"
]

df[campaigns].sum().plot(kind="bar")

plt.title("Campaign Acceptance")
plt.ylabel("Customers")
plt.show()

# %%
plt.figure(figsize=(8,5))

df["Income"].hist(bins=30)

plt.title("Income Distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()
